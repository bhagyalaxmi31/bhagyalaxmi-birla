# %%
# Import necessary libraries
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Load the dataset
# Assuming the dataset is in a CSV format. Replace 'your_dataset.csv' with your actual file path.
# For demonstration, let's create a sample dataset.
data = {
    'TransactionID': [1, 1, 1, 2, 2, 3, 3, 3, 3],
    'Item': ['Milk', 'Bread', 'Butter', 'Bread', 'Diaper', 'Milk', 'Bread', 'Diaper', 'Beer']
}
df = pd.DataFrame(data)

# Convert the dataset into a one-hot encoded format
basket = df.groupby(['TransactionID', 'Item'])['Item'].count().unstack().reset_index().fillna(0)
basket = basket.drop('TransactionID', axis=1)
basket = basket.applymap(lambda x: 1 if x > 0 else 0)

# Generate frequent itemsets
frequent_itemsets = apriori(basket, min_support=0.2, use_colnames=True)

# Generate the association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display the results
print("Frequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
print(rules)
# Out:
# Frequent Itemsets:
#      support                     itemsets
# 0   0.333333                       (Beer)
# 1   1.000000                      (Bread)
# 2   0.333333                     (Butter)
# 3   0.666667                     (Diaper)
# 4   0.666667                       (Milk)
# 5   0.333333                (Beer, Bread)
# 6   0.333333               (Beer, Diaper)
# 7   0.333333                 (Beer, Milk)
# 8   0.333333              (Butter, Bread)
# 9   0.666667              (Diaper, Bread)
# 10  0.666667                (Milk, Bread)
# 11  0.333333               (Butter, Milk)
# 12  0.333333               (Milk, Diaper)
# 13  0.333333        (Beer, Diaper, Bread)
# 14  0.333333          (Beer, Milk, Bread)
# 15  0.333333         (Milk, Beer, Diaper)
# 16  0.333333        (Butter, Milk, Bread)
# 17  0.333333        (Milk, Diaper, Bread)
# 18  0.333333  (Milk, Beer, Diaper, Bread)
#
# Association Rules:
#               antecedents            consequents  antecedent support  \
# ...
